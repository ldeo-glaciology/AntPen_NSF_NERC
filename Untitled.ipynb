# %%
import xarray as xr

# %%
A_chunks_1 = xr.open_zarr(
    "gs://ldeo-glaciology/SHIVER_zarr/Antarctica_multisource_speed.zarr",
)
# Out:
# Could not determine bucket type for bucket name ldeo-glaciology: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
# Could not determine bucket type for bucket name ldeo-glaciology: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
# Could not determine bucket type for bucket name ldeo-glaciology: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
# Could not determine bucket type for bucket name ldeo-glaciology: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
# ...

# %%
A_chunks_1.nbytes/1e9
# Out:
# 15734.583259044

# %%
A_chunks_1
# Out:
# <xarray.Dataset> Size: 16TB
# Dimensions:      (time: 2790, y: 24580, x: 28680, bnds: 2)
# Coordinates:
#   * time         (time) datetime64[ns] 22kB 1968-07-02T22:46:31.500000 ... 20...
#   * y            (y) float64 197kB 2.458e+06 2.458e+06 ... -2.458e+06 -2.458e+06
#   * x            (x) float64 229kB -2.868e+06 -2.868e+06 ... 2.868e+06 2.868e+06
#     time_bnds    (time, bnds) datetime64[ns] 45kB dask.array<chunksize=(2790, 2), meta=np.ndarray>
# Dimensions without coordinates: bnds
# Data variables:
#     data_source  (time) <U50 558kB dask.array<chunksize=(1,), meta=np.ndarray>
#     error        (time, y, x) float32 8TB dask.array<chunksize=(1, 1024, 1024), meta=np.ndarray>
#     spatial_ref  int32 4B ...
#     speed        (time, y, x) float32 8TB dask.array<chunksize=(1, 1024, 1024), meta=np.ndarray>

# %%
subset = A_chunks_1.isel(time = 2000, y = slice(15000,),  x = slice(15000,))
subset.nbytes/1e9
# Out:
# 1.800240228

# %%
coarse = subset.coarsen(x=10, y=10).mean()
coarse.compute()
# Out:
# Could not determine bucket type for bucket name ldeo-glaciology: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
# <xarray.Dataset> Size: 18MB
# Dimensions:      (y: 1500, x: 1500, bnds: 2)
# Coordinates:
#   * y            (y) float64 12kB 2.457e+06 2.455e+06 ... -5.39e+05 -5.41e+05
#   * x            (x) float64 12kB -2.867e+06 -2.865e+06 ... 1.29e+05 1.31e+05
#     time_bnds    (bnds) datetime64[ns] 16B 2021-02-09T05:35:50 2021-02-22T05:...
#     time         datetime64[ns] 8B 2021-02-15T17:35:49.500000
# Dimensions without coordinates: bnds
# Data variables:
#     data_source  <U5 20B 'SHIFT'
#     error        (y, x) float32 9MB nan nan nan nan nan ... nan nan nan nan nan
#     spatial_ref  int32 4B -2147483647
#     speed        (y, x) float32 9MB nan nan nan nan nan ... nan nan nan nan nan

# %%
coarse.speed.plot()

# %%
z
# Out:
# <zarr.hierarchy.Group '/' read-only>

# %%
type(z)
# Out:
# zarr.hierarchy.Group

# %%
z.tree()
# Out:
# Tree(nodes=(Node(disabled=True, name='/', nodes=(Node(disabled=True, icon='table', name='SNR (10, 3465, 3882) …

# %%
import xarray as xr
import gcsfs

fs = gcsfs.GCSFileSystem()
store = fs.get_mapper('gs://ldeo-glaciology/FRAM_velocity/lev_200m_timefiltered.zarr')

ds = xr.open_zarr(store, consolidated=False)  # or True, if applicable
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/backends/zarr.py:391, in _get_zarr_dims_and_attrs(zarr_obj, dimension_key, try_nczarr)
#     389 try:
#     390     # Xarray-Zarr
# --> 391     dimensions = zarr_obj.attrs[dimension_key]
#     392 except KeyError as e:
#
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/zarr/attrs.py:74, in Attributes.__getitem__(self, item)
#      73 def __getitem__(self, item):
# ---> 74     return self.asdict()[item]
#
# KeyError: '_ARRAY_DIMENSIONS'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.11/site-packages/xarray/backends/zarr.py:411, in _get_zarr_dims_and_attrs(zarr_obj, dimension_key, try_nczarr)
#     408 try:
# ...

# %%
print(list(z.array_keys()))  # Show variable names
#
# Out:
# ['SNR', 'U', 'U_filter_mask', 'U_off_ice_median', 'V', 'V_filter_mask', 'V_off_ice_median', 'date1', 'date2', 'x', 'y']

# %%
print(z['U'].attrs)  # Look for _ARRAY_DIMENSIONS
