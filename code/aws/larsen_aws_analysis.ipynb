# %%
import xarray as xr

# %%
ds = xr.open_dataset("AWS_LC.nc")
ds
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:      (datetime: 118116)
# Coordinates:
#   * datetime     (datetime) datetime64[ns] 945kB 2014-11-25T18:00:00 ... 2026...
# Data variables:
#     temperature  (datetime) float64 945kB ...

# %%
daily= ds.temperature.resample(datetime="1D").mean()
daily_std = ds.temperature.resample(datetime="1D").std()
# Out:
# /Users/jkingslake/.local/share/mamba/envs/pdem_tools/lib/python3.13/site-packages/numpy/lib/_nanfunctions_impl.py:2019: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/jkingslake/.local/share/mamba/envs/pdem_tools/lib/python3.13/site-packages/numpy/lib/_nanfunctions_impl.py:2019: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/jkingslake/.local/share/mamba/envs/pdem_tools/lib/python3.13/site-packages/numpy/lib/_nanfunctions_impl.py:2019: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/jkingslake/.local/share/mamba/envs/pdem_tools/lib/python3.13/site-packages/numpy/lib/_nanfunctions_impl.py:2019: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# ...

# %%
daily_std.plot()
