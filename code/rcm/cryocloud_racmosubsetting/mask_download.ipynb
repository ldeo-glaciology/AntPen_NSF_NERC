# %% [markdown]
# # Downloads and plots the mask that was supplied with the latest RACMO dataset
#
# http://climato.be/ftp/climato/bnoel/Share-public/.Kingslake/AIS_topo_icemask_lsm_lon_lat_2km.nc

# %%
import xarray as xr

# %%
# download 
# !wget http://climato.be/ftp/climato/bnoel/Share-public/.Kingslake/AIS_topo_icemask_lsm_lon_lat_2km.nc
# Out:
# --2026-06-03 13:21:40--  http://climato.be/ftp/climato/bnoel/Share-public/.Kingslake/AIS_topo_icemask_lsm_lon_lat_2km.nc
# wget: /Users/jkingslake/.netrc:1: unknown token "cmake"
# wget: /Users/jkingslake/.netrc:1: unknown token "-DOpenMP_CXX_FLAGS="-Xpreprocessor"
# wget: /Users/jkingslake/.netrc:1: unknown token "-fopenmp"
# wget: /Users/jkingslake/.netrc:1: unknown token "-I/usr/local/opt/libomp/include""
# wget: /Users/jkingslake/.netrc:1: unknown token "-DOpenMP_CXX_LIB_NAMES="omp""
# wget: /Users/jkingslake/.netrc:1: unknown token "-DOpenMP_omp_LIBRARY=/usr/local/opt/libomp/lib/libomp.dylib"
# wget: /Users/jkingslake/.netrc:1: unknown token ".."
# Resolving climato.be (climato.be)... 139.165.67.19
# Connecting to climato.be (climato.be)|139.165.67.19|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51523615 (49M) [application/x-netcdf]
# Saving to: ‘AIS_topo_icemask_lsm_lon_lat_2km.nc’
#
# ...

# %%
mask = xr.open_dataset('AIS_topo_icemask_lsm_lon_lat_2km.nc')

# %%
mask
# Out:
# <xarray.Dataset> Size: 256MB
# Dimensions:     (x: 2778, y: 2303)
# Coordinates:
#   * x           (x) float32 11kB -2.731e+06 -2.729e+06 ... 2.821e+06 2.823e+06
#   * y           (y) float32 9kB -2.232e+06 -2.23e+06 ... 2.37e+06 2.372e+06
# Data variables:
#     BASINS      (y, x) float32 26MB ...
#     SECTORS     (y, x) float32 26MB ...
#     Topography  (y, x) float32 26MB ...
#     Icemask     (y, x) float32 26MB ...
#     LSM         (y, x) float32 26MB ...
#     AIS         (y, x) float32 26MB ...
#     SHELF       (y, x) float32 26MB ...
#     ROCK        (y, x) float32 26MB ...
#     lon         (y, x) float32 26MB ...
#     lat         (y, x) float32 26MB ...
# Attributes:
#     CDI:          Climate Data Interface version 2.4.4 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     institution:  IMAU (Brice Noel)
#     title:        Masks Antarctic Ice Sheet at 1km
#     grid:         Map Projection:Polar Stereographic Ellipsoid - Map Referenc...
# ...

# %%
mask.Topography.plot()

# %%
mask.ROCK.plot()

# %%
mask.BASINS.plot()
