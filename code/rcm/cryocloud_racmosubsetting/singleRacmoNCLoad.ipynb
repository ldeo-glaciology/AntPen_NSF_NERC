# %% [markdown]
# # Loads one of the RACMO netcdfs supplied by Brice Noel

# %%
import xarray as xr

# %%
ds = xr.open_dataset('../../../data/rcm/ff10m.1979_AMJ.BN_RACMO2.3p2_ANT27_ERA5_3h.AIS.2km.DD.nc')

# %%
ds
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:    (time: 91, x: 2778, y: 2303)
# Coordinates:
#   * time       (time) datetime64[ns] 728B 1979-04-01 1979-04-02 ... 1979-06-30
#   * x          (x) float32 11kB -2.731e+06 -2.729e+06 ... 2.821e+06 2.823e+06
#   * y          (y) float32 9kB -2.232e+06 -2.23e+06 ... 2.37e+06 2.372e+06
# Data variables:
#     ff10mcorr  (time, y, x) float32 2GB ...
# Attributes:
#     CDI:          Climate Data Interface version 2.4.4 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     institution:  IMAU (Brice Noel)
#     title:        Daily mean ff10m field at 2km (RACMO2.3p2 ANT27 ERA5)
#     grid:         Map Projection: Antarctic Polar Stereographic EPSG3031 - Ma...
#     history:      Wed May 20 18:55:10 2026: cdo -f nc4 -z zip_5 copy ff10m/ff...
#     netcdf:       4.9.1 of Feb  9 2023 13:56:58 $
#     CDO:          Climate Data Operators version 2.4.4 (https://mpimet.mpg.de...
